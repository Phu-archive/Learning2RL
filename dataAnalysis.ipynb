# %%
import plot_result
# %matplotlib inline

# %% [markdown]
# ## Plotting the value
# The hyperparameters come from the lowest average negative regret over the testing time.

# %%
plot_result.show_value(plot_variable="total_regret")

# %%
plot_result.show_value(plot_variable="average_reward")

# %% [markdown]
# ### Quick Analysis
# As you can see, althrough the regret over the testing time is similar, during the training time the average reward -- learning of 3e-5 and 1e-5 is more promissing in stability.
#
# We wil have to investigave on the cumulative regret at testing time. (forgot to add that 😭)
